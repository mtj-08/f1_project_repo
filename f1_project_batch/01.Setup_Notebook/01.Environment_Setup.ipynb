-- %% [markdown]
-- ### 1. Setting up the environment for the Project
-- 1. Create external location from ADLS gen2 container databricksf1projectext-f1project
-- 2. Create catalog formula1
-- 3. Create schema Landing, Bronze, Silver and Gold
-- 4. Create volume files in Landing schema

-- %%
%fs ls 'abfss://f1project@databricksf1projectext.dfs.core.windows.net/'

-- %% [markdown]
-- ## Creating external location (SQL)

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS databricksf1projectext_f1project
URL 'abfss://f1project@databricksf1projectext.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `db-project-sc`)
COMMENT 'External ADLS location for source data'

-- %% [markdown]
-- ## Creating a new catalog

-- %%
CREATE CATALOG IF NOT EXISTS formula1
MANAGED LOCATION 'abfss://f1project@databricksf1projectext.dfs.core.windows.net/'
COMMENT 'Main catalog for the f1 project'

-- %%
USE CATALOG formula1

-- %%
show schemas

-- %% [markdown]
-- ## Creating schema Landing, Bronze, Silver and Gold

-- %%
CREATE SCHEMA IF NOT EXISTS landing;
CREATE SCHEMA IF NOT EXISTS bronze
      MANAGED LOCATION 'abfss://f1project@databricksf1projectext.dfs.core.windows.net/';
CREATE SCHEMA IF NOT EXISTS silver
      MANAGED LOCATION 'abfss://f1project@databricksf1projectext.dfs.core.windows.net/';
CREATE SCHEMA IF NOT EXISTS gold
      MANAGED LOCATION 'abfss://f1project@databricksf1projectext.dfs.core.windows.net/';

-- %% [markdown]
-- ## Creating external volume files under the landing schema

-- %%
CREATE EXTERNAL VOLUME formula1.landing.files
LOCATION 'abfss://f1project@databricksf1projectext.dfs.core.windows.net/landing'
COMMENT 'landing files volume'

-- %%
%fs ls /Volumes/formula1/landing/files
