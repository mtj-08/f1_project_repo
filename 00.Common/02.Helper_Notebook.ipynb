# %%
from pyspark.sql import functions as F

def add_timestamp_metadata(df):
    return (
          df.withColumn('ingestion_timestamp', F.current_timestamp()).withColumn('SourceFile', F.col('_metadata.file_path'))
)
